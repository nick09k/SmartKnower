# %% [markdown]
# <a href="https://colab.research.google.com/github/nick09k/SmartKnower/blob/master/mini_linear_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv('/content/drive/My Drive/smartknower/Admission_Predict.csv')

# %%
df
# Out:
#      Serial No.  GRE Score  TOEFL Score  ...  CGPA  Research  Chance of Admit
# 0             1        337          118  ...  9.65         1              0.92
# 1             2        324          107  ...  8.87         1              0.76
# 2             3        316          104  ...  8.00         1              0.72
# 3             4        322          110  ...  8.67         1              0.80
# 4             5        314          103  ...  8.21         0              0.65
# ..          ...        ...          ...  ...   ...       ...               ...
# 395         396        324          110  ...  9.04         1              0.82
# 396         397        325          107  ...  9.11         1              0.84
# 397         398        330          116  ...  9.45         1              0.91
# 398         399        312          103  ...  8.78         0              0.67
# 399         400        333          117  ...  9.66         1              0.95
#
# [400 rows x 9 columns]

# %%
df.drop(['University Rating'], axis = 1)
# Out:
#      Serial No.  GRE Score  TOEFL Score  ...  CGPA  Research  Chance of Admit
# 0             1        337          118  ...  9.65         1              0.92
# 1             2        324          107  ...  8.87         1              0.76
# 2             3        316          104  ...  8.00         1              0.72
# 3             4        322          110  ...  8.67         1              0.80
# 4             5        314          103  ...  8.21         0              0.65
# ..          ...        ...          ...  ...   ...       ...               ...
# 395         396        324          110  ...  9.04         1              0.82
# 396         397        325          107  ...  9.11         1              0.84
# 397         398        330          116  ...  9.45         1              0.91
# 398         399        312          103  ...  8.78         0              0.67
# 399         400        333          117  ...  9.66         1              0.95
#
# [400 rows x 8 columns]

# %%
x =df.iloc[:,1:8].values
y = df.iloc[:,8].values

# %%
x
# Out:
# array([[337.  , 118.  ,   4.  , ...,   4.5 ,   9.65,   1.  ],
#        [324.  , 107.  ,   4.  , ...,   4.5 ,   8.87,   1.  ],
#        [316.  , 104.  ,   3.  , ...,   3.5 ,   8.  ,   1.  ],
#        ...,
#        [330.  , 116.  ,   4.  , ...,   4.5 ,   9.45,   1.  ],
#        [312.  , 103.  ,   3.  , ...,   4.  ,   8.78,   0.  ],
#        [333.  , 117.  ,   4.  , ...,   4.  ,   9.66,   1.  ]])

# %%
train_X = x[0:280]
train_Y = y[0:280]

test_X = x[281:399]
test_Y = y[281:399]

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(train_X,train_Y)
y_pred = model.predict(test_X)
y_pred
# Out:
# array([0.82030786, 0.73435383, 0.77180666, 0.93434457, 0.8818402 ,
#        0.88578309, 0.85117284, 0.78390933, 0.74850332, 0.5565126 ,
#        0.53763464, 0.5473475 , 0.61429304, 0.63119064, 0.65030104,
#        0.70206035, 0.83340158, 0.86775359, 0.70721665, 0.58914655,
#        0.71533666, 0.69424066, 0.73261352, 0.63194407, 0.76335609,
#        0.80169477, 0.82162674, 0.67809034, 0.69224891, 0.74345493,
#        0.83403125, 0.79323114, 0.57881563, 0.6340246 , 0.60409878,
#        0.5299871 , 0.55463428, 0.73723607, 0.76653798, 0.71012162,
#        0.7230318 , 0.67525911, 0.59419405, 0.63792641, 0.84568604,
#        0.55264589, 0.51880793, 0.77891411, 0.49776531, 0.75515591,
#        0.60715022, 0.6341683 , 0.72963814, 0.74036356, 0.84583844,
#        0.71519001, 0.93648419, 0.7846608 , 0.77729699, 0.69034642,
#        0.77078857, 0.63441449, 0.61697371, 0.45043115, 0.49740749,
#        0.50455431, 0.4185884 , 0.45063951, 0.60946248, 0.69380947,
#        0.78074463, 0.614334  , 0.58325982, 0.52079095, 0.64922645,
#        0.78530205, 0.59931998, 0.53975313, 0.63923267, 0.78957216,
#        0.89753985, 0.91433531, 0.63110672, 0.75487294, 0.82471441,
#        0.72301808, 0.50870391, 0.49650572, 0.58500297, 0.61036919,
#        0.80592993, 0.93032455, 0.72184069, 0.5598609 , 0.5294858 ,
#        0.45891671, 0.46980104, 0.51020513, 0.64972242, 0.77019465,
#        0.73630015, 0.82872147, 0.619475  , 0.96066096, 0.97969133,
#        0.58620451, 0.62559479, 0.50820829, 0.73142058, 0.6178077 ,
#        0.70593147, 0.82305275, 0.69767979, 0.85001614, 0.79942645,
#        0.80382014, 0.90269003, 0.72162393])

# %%
test_Y
# Out:
# array([0.8 , 0.81, 0.8 , 0.94, 0.93, 0.92, 0.89, 0.82, 0.79, 0.58, 0.56,
#        0.56, 0.64, 0.61, 0.68, 0.76, 0.86, 0.9 , 0.71, 0.62, 0.66, 0.65,
#        0.73, 0.62, 0.74, 0.79, 0.8 , 0.69, 0.7 , 0.76, 0.84, 0.78, 0.67,
#        0.66, 0.65, 0.54, 0.58, 0.79, 0.8 , 0.75, 0.73, 0.72, 0.62, 0.67,
#        0.81, 0.63, 0.69, 0.8 , 0.43, 0.8 , 0.73, 0.75, 0.71, 0.73, 0.83,
#        0.72, 0.94, 0.81, 0.81, 0.75, 0.79, 0.58, 0.59, 0.47, 0.49, 0.47,
#        0.42, 0.57, 0.62, 0.74, 0.73, 0.64, 0.63, 0.59, 0.73, 0.79, 0.68,
#        0.7 , 0.81, 0.85, 0.93, 0.91, 0.69, 0.77, 0.86, 0.74, 0.57, 0.51,
#        0.67, 0.72, 0.89, 0.95, 0.79, 0.39, 0.38, 0.34, 0.47, 0.56, 0.71,
#        0.78, 0.73, 0.82, 0.62, 0.96, 0.96, 0.46, 0.53, 0.49, 0.76, 0.64,
#        0.71, 0.84, 0.77, 0.89, 0.82, 0.84, 0.91, 0.67])

# %%
from sklearn import metrics
metrics.mean_squared_error(test_Y,y_pred)
# Out:
# 0.0032743631972153198

# %%
metrics.r2_score(test_Y,y_pred)
# Out:
# 0.8252005813913257

# %%
sns.pairplot(df,x_vars=['GRE Score','TOEFL Score','SOP','LOR ','CGPA','Research'],y_vars=['Chance of Admit '],size=9, aspect=0.9, kind='reg')
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/axisgrid.py:2071: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
