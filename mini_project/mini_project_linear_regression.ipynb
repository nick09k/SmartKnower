# %% [markdown]
# <a href="https://colab.research.google.com/github/nick09k/SmartKnower/blob/master/mini_project_linear_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv('/content/drive/My Drive/smartknower/Admission_Predict.csv')

# %%
df
# Out:
#      Serial No.  GRE Score  TOEFL Score  ...  CGPA  Research  Chance of Admit
# 0             1        337          118  ...  9.65         1              0.92
# 1             2        324          107  ...  8.87         1              0.76
# 2             3        316          104  ...  8.00         1              0.72
# 3             4        322          110  ...  8.67         1              0.80
# 4             5        314          103  ...  8.21         0              0.65
# ..          ...        ...          ...  ...   ...       ...               ...
# 395         396        324          110  ...  9.04         1              0.82
# 396         397        325          107  ...  9.11         1              0.84
# 397         398        330          116  ...  9.45         1              0.91
# 398         399        312          103  ...  8.78         0              0.67
# 399         400        333          117  ...  9.66         1              0.95
#
# [400 rows x 9 columns]

# %%
df.drop(['University Rating'], axis = 1)
# Out:
#      Serial No.  GRE Score  TOEFL Score  ...  CGPA  Research  Chance of Admit
# 0             1        337          118  ...  9.65         1              0.92
# 1             2        324          107  ...  8.87         1              0.76
# 2             3        316          104  ...  8.00         1              0.72
# 3             4        322          110  ...  8.67         1              0.80
# 4             5        314          103  ...  8.21         0              0.65
# ..          ...        ...          ...  ...   ...       ...               ...
# 395         396        324          110  ...  9.04         1              0.82
# 396         397        325          107  ...  9.11         1              0.84
# 397         398        330          116  ...  9.45         1              0.91
# 398         399        312          103  ...  8.78         0              0.67
# 399         400        333          117  ...  9.66         1              0.95
#
# [400 rows x 8 columns]

# %%
x =df.iloc[:,1:8].values
y = df.iloc[:,8].values

# %%
x
# Out:
# array([[337.  , 118.  ,   4.  , ...,   4.5 ,   9.65,   1.  ],
#        [324.  , 107.  ,   4.  , ...,   4.5 ,   8.87,   1.  ],
#        [316.  , 104.  ,   3.  , ...,   3.5 ,   8.  ,   1.  ],
#        ...,
#        [330.  , 116.  ,   4.  , ...,   4.5 ,   9.45,   1.  ],
#        [312.  , 103.  ,   3.  , ...,   4.  ,   8.78,   0.  ],
#        [333.  , 117.  ,   4.  , ...,   4.  ,   9.66,   1.  ]])

# %%
train_X = x[0:320]
train_Y = y[0:320]

test_X = x[321:399]
test_Y = y[321:399]

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(train_X,train_Y)
y_pred = model.predict(test_X)
y_pred
# Out:
# array([0.72203386, 0.67677871, 0.59733978, 0.64089895, 0.84693367,
#        0.55744028, 0.52363161, 0.78072893, 0.50176421, 0.75622165,
#        0.60886123, 0.63700256, 0.73039932, 0.74265233, 0.84665236,
#        0.71900317, 0.93826698, 0.78616077, 0.77831778, 0.69239919,
#        0.77105855, 0.63837646, 0.61947798, 0.45378942, 0.49715092,
#        0.50689174, 0.42097089, 0.45273218, 0.61146143, 0.69435398,
#        0.78143478, 0.61497861, 0.58817085, 0.52371549, 0.65034416,
#        0.78478939, 0.60101547, 0.54221847, 0.64188232, 0.78915062,
#        0.89907141, 0.91435871, 0.63404559, 0.75529136, 0.82675366,
#        0.72191176, 0.50874006, 0.49829108, 0.58508166, 0.61303763,
#        0.80725951, 0.93181287, 0.72291962, 0.56166246, 0.53224811,
#        0.46217039, 0.47410566, 0.51177529, 0.64876466, 0.76954584,
#        0.73656678, 0.83003875, 0.62310692, 0.95963614, 0.98104225,
#        0.58867943, 0.6280773 , 0.51190997, 0.73159436, 0.61957874,
# ...

# %%
test_Y
# Out:
# array([0.73, 0.72, 0.62, 0.67, 0.81, 0.63, 0.69, 0.8 , 0.43, 0.8 , 0.73,
#        0.75, 0.71, 0.73, 0.83, 0.72, 0.94, 0.81, 0.81, 0.75, 0.79, 0.58,
#        0.59, 0.47, 0.49, 0.47, 0.42, 0.57, 0.62, 0.74, 0.73, 0.64, 0.63,
#        0.59, 0.73, 0.79, 0.68, 0.7 , 0.81, 0.85, 0.93, 0.91, 0.69, 0.77,
#        0.86, 0.74, 0.57, 0.51, 0.67, 0.72, 0.89, 0.95, 0.79, 0.39, 0.38,
#        0.34, 0.47, 0.56, 0.71, 0.78, 0.73, 0.82, 0.62, 0.96, 0.96, 0.46,
#        0.53, 0.49, 0.76, 0.64, 0.71, 0.84, 0.77, 0.89, 0.82, 0.84, 0.91,
#        0.67])

# %%
from sklearn import metrics
metrics.mean_squared_error(test_Y,y_pred)
# Out:
# 0.00426868493049797

# %%
metrics.r2_score(test_Y,y_pred)
# Out:
# 0.8052419142850634

# %%
sns.pairplot(df,x_vars=['GRE Score','TOEFL Score','SOP','LOR ','CGPA','Research'],y_vars=['Chance of Admit '],size=9, aspect=0.9, kind='reg')
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/axisgrid.py:2071: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
